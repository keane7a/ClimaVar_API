# %%
# Import goes here
import requests
import json
from pprint import pprint

# %%
# Check create user
prod = False
base_url = (
    "https://climavarapi-production.up.railway.app/"
    if prod
    else "http://127.0.0.1:8000/"
)

createUser_url = base_url + "api/users/generate-token/"
data = {
    "username": "keane",
    "password": "Ex&ter06NCITeam",
}

res = requests.post(createUser_url, json=data)
token = res.json().get("token")
print(res)
print(res.json())
# Out:
# <Response [200]>
# {'token': '1c89c9ef4c197378d911a1bf44378a7f83f555a6'}

# %%
# Check misclassifcation
createUser_url = base_url + "api/misclassifications/check-misclassification/"
data = {
    # "text": "Many online posts falsely claim that climate change is a natural cycle unaffected by humans. In reality, scientific evidence shows that rising global temperatures are driven primarily by human activities such as burning fossil fuels and deforestation.",
    "text": "Climate change is a religion"
}

header = {
    "Authorization": "Token " + token,
}
print(createUser_url, header)
res = requests.post(createUser_url, headers=header, json=data, timeout=120)

print(res)
print(res.status_code)
pprint(res.json())
# Out:
# http://127.0.0.1:8000/api/misclassifications/check-misclassification/ {'Authorization': 'Token 1c89c9ef4c197378d911a1bf44378a7f83f555a6'}
# <Response [200]>
# 200
# {'llm_response': 'Offside! Claiming climate change is a religion is like '
#                  "saying a penalty kick is just a friendly chat—it's all about "
#                  "the evidence, and the science shows it's a real "
#                  'game-changer, not a belief system!',
#  'misinformation': 1,
#  'references': ['Climate Change 2021: The Physical Science Basis, page number '
#                 '2408 (2021) - '
#                 'https://www.ipcc.ch/report/ar6/wg1/downloads/report/IPCC_AR6_WGI_FullReport.pdf']}

# %%
res.json()
# Out:
# {'llm_response': "Offside! Claiming climate change is a religion is like saying a penalty kick is just a friendly chat—it's all about the evidence, and the science shows it's a real game-changer, not a belief system!",
#  'misinformation': 1,
#  'references': ['Climate Change 2021: The Physical Science Basis, page number 2408 (2021) - https://www.ipcc.ch/report/ar6/wg1/downloads/report/IPCC_AR6_WGI_FullReport.pdf']}

# %%
res.json()["llm_response"]
# Out:
# "Offside! Claiming climate change is a religion is a total foul—it's backed by solid evidence and scientific consensus, not faith, so let's keep our eyes on the ball and focus on the facts!"

# %%
texts = [  # (english, spanish)
    (
        "Scientists agree that human activity is the main driver of recent climate change.",
        "Los científicos coinciden en que la actividad humana es la principal causa del cambio climático reciente.",
    ),
    (
        "Some social media posts falsely claim that global warming stopped in 1998.",
        "Algunas publicaciones en redes sociales afirman falsamente que el calentamiento global se detuvo en 1998.",
    ),
    (
        "The Arctic is warming nearly four times faster than the global average.",
        "El Ártico se está calentando casi cuatro veces más rápido que el promedio mundial.",
    ),
    (
        "A common myth says volcanoes emit more CO₂ than humans, but that's not true.",
        "Un mito común dice que los volcanes emiten más CO₂ que los humanos, pero eso no es cierto",
    ),
    (
        "Renewable energy sources like wind and solar are now cheaper than coal in many regions.",
        "Las fuentes de energía renovables, como la eólica y la solar, son ahora más baratas que el carbón en muchas regiones.",
    ),
    (
        "Certain blogs spread the false idea that climate change is a natural cycle with no human impact.",
        "Ciertos blogs difunden la falsa idea de que el cambio climático es un ciclo natural sin impacto humano.",
    ),
    (
        "Ocean acidification is a direct result of increased carbon dioxide in the atmosphere.",
        "La acidificación de los océanos es resultado directo del aumento del dióxido de carbono en la atmósfera.",
    ),
    (
        "Misleading videos sometimes use cold weather events to argue that global warming isn't real.",
        "Algunos videos engañosos a veces utilizan eventos de frío extremo para argumentar que el calentamiento global no es real.",
    ),
    (
        "The last decade was the hottest ever recorded since reliable measurements began.",
        "La última década fue la más cálida jamás registrada desde que comenzaron las mediciones confiables.",
    ),
    (
        "Some conspiracy theories claim climate change is a hoax invented for political control.",
        "Algunas teorías de la conspiración afirman que el cambio climático es un engaño inventado para el control político.",
    ),
]

responses = []

for i, text in enumerate(texts):
    print(i)
    data = {"text": text[1]}  # Spanish text
    res = requests.post(createUser_url, headers=header, json=data, timeout=120)
    print(res.status_code)
    print(res.text)
    if res.status_code == 200:
        responses.append(
            (text[1], res.json()["llm_response"])
        )  # (English, Spanish, Response)

print(responses)
# Out:
# 0
# 200
# {"llm_response":"¡Claro que sí! ¡Los científicos están dando la voz de alarma sobre la actividad humana como el jugador estrella en el reciente cambio climático, con los gases de efecto invernadero alcanzando niveles récord como un delantero en llamas!\nReferences: Climate Change 2021: The Physical Science Basis, page number 2408 (2021) - https://www.ipcc.ch/report/ar6/wg1/downloads/report/IPCC_AR6_WGI_FullReport.pdf","misinformation":false}
# 1
# 200
# {"llm_response":"¡Fuera de juego! Esa afirmación de 'hiatus' es solo una descarada distracción: las temperaturas globales siguen en aumento, y los últimos datos muestran que la tendencia de calentamiento es más fuerte que nunca, ¡así que no hay desaceleración en este partido!\nReferences: Climate Change 2021: The Physical Science Basis, page number 2408 (2021) - https://www.ipcc.ch/report/ar6/wg1/downloads/report/IPCC_AR6_WGI_FullReport.pdf","misinformation":true}
# 2
# 200
# ...

# %%
for i, (q, a) in enumerate(texts):
    print(f"{i}. {q}")
    # print(f"statement {i}")
    # print(f"Query: {q}")
    # print("\n")
    # print(f"Answer: {a}")
    # print("\n\n")
# Out:
# 0. Scientists agree that human activity is the main driver of recent climate change.
# 1. Some social media posts falsely claim that global warming stopped in 1998.
# 2. The Arctic is warming nearly four times faster than the global average.
# 3. A common myth says volcanoes emit more CO₂ than humans, but that's not true.
# 4. Renewable energy sources like wind and solar are now cheaper than coal in many regions.
# 5. Certain blogs spread the false idea that climate change is a natural cycle with no human impact.
# 6. Ocean acidification is a direct result of increased carbon dioxide in the atmosphere.
# 7. Misleading videos sometimes use cold weather events to argue that global warming isn't real.
# 8. The last decade was the hottest ever recorded since reliable measurements began.
# 9. Some conspiracy theories claim climate change is a hoax invented for political control.

# %%
get_misclassification_url = createUser_url = base_url + "api/"
res =
