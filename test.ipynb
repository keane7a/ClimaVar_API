# %%
# Import goes here
import requests
import json

# %%
# Check create user
base_url = (
    "http://127.0.0.1:8000/"  # "https://climavarapi-production.up.railway.app/" #
)
createUser_url = base_url + "api/users/generate-token/"
data = {
    "username": "loveable",
    "password": "Ex&ter06NCITeam",
}

res = requests.post(createUser_url, json=data)
token = res.json().get("token")
print(res)
print(res.json())
# Out:
# <Response [200]>
# {'token': 'b9a31448ac08f21361e6334c6461ef5db7e16b96'}

# %%
# Check misclassifcation
createUser_url = base_url + "api/misclassifications/check-misclassification/"
data = {
    "text": "Ice is melting due to climate change",
}
header = {
    "Authorization": "Token " + token,
}
print(header)
res = requests.post(createUser_url, headers=header, json=data, timeout=60)

print(res)
print(res.status_code)
print(res.json())
# Out:
# {'Authorization': 'Token b9a31448ac08f21361e6334c6461ef5db7e16b96'}
# <Response [200]>
# 200
# {'llm_response': 'FINAL: Offside! The ice sheets in Greenland and Antarctica are melting faster than a striker missing an open goal, and that’s all thanks to climate change—no doubt about it!\nReferences: Climate Change Indicators in the United States - Fifth Edition, page number 92 (2024) - https://www.epa.gov/system/files/documents/2024-07/climate_indicators_2024.pdf', 'misinformation': True}
