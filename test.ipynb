# %%
# Import goes here
import requests
import json

# %%
# Check create user
base_url = (
    "https://climavarapi-production.up.railway.app/"  # "http://127.0.0.1:8000/" #
)
createUser_url = base_url + "api/users/generate-token/"
data = {
    "username": "loveable",
    "password": "Ex&ter06NCITeam",
}

res = requests.post(createUser_url, json=data)
token = res.json().get("token")
print(res)
print(res.json())
# Out:
# <Response [200]>
# {'token': '89380d89bd6b428eea984d180de8fe117f1e166c'}

# %%
# Check misclassifcation
createUser_url = base_url + "api/misclassifications/check-misclassification/"
data = {
    "text": "climate change is a hoax invented by the Chinese",
}
header = {
    "Authorization": "Token " + token,
}
print(header)
res = requests.post(createUser_url, headers=header, json=data, timeout=60)

print(res)
print(res.status_code)
print(res.json())
# Out:
# {'Authorization': 'Token 89380d89bd6b428eea984d180de8fe117f1e166c'}
# <Response [200]>
# 200
# {'response': 'Climate change is supported by a vast majority of climate scientists and extensive research, making it a well-established fact rather than a deceptive play from the sidelines.', 'misinformation': True}
