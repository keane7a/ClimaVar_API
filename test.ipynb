# %%
# Import goes here 
import requests
import json

# %%
url = "http://127.0.0.1:8000/check-misinformation/"
data = {
    "text": "climate change is real and is happening right now", 
    "token": "ClimaVar2025"
}
res = requests.post(url, data=json.dumps(data))
print(res)
print(res.json())
# Out:
# <Response [200]>
# {'response': 'Climate change is a pressing issue that is currently affecting our planet, much like a team facing a formidable opponent on the field.', 'misinformation': True}

# %%
# Check create user 
createUser_url = 'http://127.0.0.1:8000/api/users/generate_token/'
data = {
    "username": "bob123",
    "password": "Exeter06NCITeam",
}

res = requests.post(createUser_url, json=data)
token = res.json().get("token")
print(res)
print(res.json())
# Out:
# <Response [200]>
# {'token': '6af2387bb2fa0eddfcdd99a01f03b1e3bb0af5c8'}

# %%
# Check misclassifcation
createUser_url = 'http://127.0.0.1:8000/api/misclassifications/check-misclassification/'
data = {
    "text": "climate change is a hoax invented by the Chinese",
}
header = {
    "Authorization": "Token " + token,
}
print(header)
res = requests.post(createUser_url, headers=header, json=data)

print(res)
print(res.status_code)
print(res.json())
# Out:
# {'Authorization': 'Token 6af2387bb2fa0eddfcdd99a01f03b1e3bb0af5c8'}
# <Response [200]>
# 200
# {'response': 'Climate change is supported by a vast majority of climate scientists worldwide, making it a well-established fact rather than a deceptive play from the sidelines.', 'misinformation': True}
